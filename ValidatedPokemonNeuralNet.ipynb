# %% [markdown]
# ### Predicting Legendary Pokemon using Neural Networks
# #### Sam Berkson
# #### CPSC 323
#
# Today, ill be utilizing a neural network to predict whether a Pokemon is legendary based on its:
# * HP
# * Attack
# * Defense
# * Special Attack
# * Special Defence
# * Speed
#
# First, we need to import our libraries and read in our data.  Then we split in into our training, testing, and validation set.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import sklearn 
from sklearn import preprocessing
from sklearn import utils
from sklearn import model_selection
from sklearn import metrics
from sklearn.metrics import confusion_matrix, classification_report

df = pd.read_csv('Pokemon.csv')
df.head()
df.corr()

# Split data into train, test, and validation sets
X_train, x_test, y_train, y_test = model_selection.train_test_split(df[['HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed']], df['Legendary'], test_size=0.3, random_state=1)
X_train, X_val, y_train, y_val = model_selection.train_test_split(X_train, y_train, test_size=0.1, random_state=1)

# %% [markdown]
# Now that we've split our data, we can implement our neural network.  I used a 5 layer network, using a relu activation function. I compile the model using the adam optimizer, tracking loss as mean squared error (MSE), and tracking my accuracy and mse as metrics.  Next, I ran the model over a different number of epochs to see which yielded the best results.

# %%
model = keras.Sequential([
    layers.Dense(30, activation='relu', input_shape=[6]),
    layers.Dense(30, activation='relu'),
    layers.Dense(30, activation='relu'),
    layers.Dense(6, activation='relu'),
    layers.Dense(1, activation='relu')
])

model = keras.Sequential([
    layers.Dense(30, activation='relu', input_shape=[6]),
    layers.Dense(1, activation='relu')
])

model.compile(optimizer='adam',
                loss='mse',
                metrics=['accuracy', 'mse'])

model.summary()

history = model.fit(X_train, y_train, epochs=100, batch_size=26, validation_data=(X_val, y_val))
model.evaluate(x_test, y_test)
y_pred = model.predict(x_test)
model.save('PokemonNeuralNet.h5')
# Out:
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_43 (Dense)            (None, 30)                210
#
#  dense_44 (Dense)            (None, 1)                 31
#
# =================================================================
# Total params: 241
# Trainable params: 241
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 20/20 [==============================] - 1s 10ms/step - loss: 7123.6597 - accuracy: 0.0774 - mse: 7123.6597 - val_loss: 3652.1387 - val_accuracy: 0.0893 - val_mse: 3652.1387
# Epoch 2/100
# 20/20 [==============================] - 0s 2ms/step - loss: 2837.2739 - accuracy: 0.0893 - mse: 2837.2739 - val_loss: 1167.0375 - val_accuracy: 0.2143 - val_mse: 1167.0375
# Epoch 3/100
# 20/20 [==============================] - 0s 2ms/step - loss: 874.9835 - accuracy: 0.2560 - mse: 874.9835 - val_loss: 287.6856 - val_accuracy: 0.5179 - val_mse: 287.6856
# Epoch 4/100
# 20/20 [==============================] - 0s 2ms/step - loss: 241.3121 - accuracy: 0.5754 - mse: 241.3121 - val_loss: 80.7753 - val_accuracy: 0.6786 - val_mse: 80.7753
# Epoch 5/100
# 20/20 [==============================] - 0s 2ms/step - loss: 105.4266 - accuracy: 0.7421 - mse: 105.4266 - val_loss: 24.3645 - val_accuracy: 0.7500 - val_mse: 24.3645
# Epoch 6/100
# 20/20 [==============================] - 0s 2ms/step - loss: 59.0902 - accuracy: 0.8016 - mse: 59.0902 - val_loss: 9.6684 - val_accuracy: 0.8036 - val_mse: 9.6684
# Epoch 7/100
# 20/20 [==============================] - 0s 2ms/step - loss: 42.3359 - accuracy: 0.8492 - mse: 42.3359 - val_loss: 4.0098 - val_accuracy: 0.8571 - val_mse: 4.0098
# Epoch 8/100
# 20/20 [==============================] - 0s 2ms/step - loss: 30.3689 - accuracy: 0.8671 - mse: 30.3689 - val_loss: 1.9019 - val_accuracy: 0.8750 - val_mse: 1.9019
# Epoch 9/100
# 20/20 [==============================] - 0s 2ms/step - loss: 23.7614 - accuracy: 0.8829 - mse: 23.7614 - val_loss: 0.8394 - val_accuracy: 0.8929 - val_mse: 0.8394
# Epoch 10/100
# 20/20 [==============================] - 0s 2ms/step - loss: 17.8622 - accuracy: 0.8909 - mse: 17.8622 - val_loss: 0.2452 - val_accuracy: 0.8929 - val_mse: 0.2452
# Epoch 11/100
# 20/20 [==============================] - 0s 2ms/step - loss: 14.2808 - accuracy: 0.8968 - mse: 14.2808 - val_loss: 0.0925 - val_accuracy: 0.9107 - val_mse: 0.0925
# Epoch 12/100
# 20/20 [==============================] - 0s 2ms/step - loss: 12.0215 - accuracy: 0.8988 - mse: 12.0215 - val_loss: 0.0893 - val_accuracy: 0.9107 - val_mse: 0.0893
# Epoch 13/100
# 20/20 [==============================] - 0s 2ms/step - loss: 9.9139 - accuracy: 0.9028 - mse: 9.9139 - val_loss: 0.0893 - val_accuracy: 0.9107 - val_mse: 0.0893
# Epoch 14/100
# 20/20 [==============================] - 0s 2ms/step - loss: 8.3194 - accuracy: 0.9048 - mse: 8.3194 - val_loss: 0.0893 - val_accuracy: 0.9107 - val_mse: 0.0893
# Epoch 15/100
# 20/20 [==============================] - 0s 2ms/step - loss: 7.3533 - accuracy: 0.9067 - mse: 7.3533 - val_loss: 0.0893 - val_accuracy: 0.9107 - val_mse: 0.0893
# Epoch 16/100
# 20/20 [==============================] - 0s 2ms/step - loss: 6.4145 - accuracy: 0.9067 - mse: 6.4145 - val_loss: 0.0893 - val_accuracy: 0.9107 - val_mse: 0.0893
# Epoch 17/100
# 20/20 [==============================] - 0s 2ms/step - loss: 5.5662 - accuracy: 0.9048 - mse: 5.5662 - val_loss: 0.0893 - val_accuracy: 0.9107 - val_mse: 0.0893
# Epoch 18/100
# 20/20 [==============================] - 0s 2ms/step - loss: 4.9424 - accuracy: 0.9048 - mse: 4.9424 - val_loss: 0.0893 - val_accuracy: 0.9107 - val_mse: 0.0893
# Epoch 19/100
# 20/20 [==============================] - 0s 2ms/step - loss: 4.4693 - accuracy: 0.9087 - mse: 4.4693 - val_loss: 0.0893 - val_accuracy: 0.9107 - val_mse: 0.0893
# Epoch 20/100
# 20/20 [==============================] - 0s 2ms/step - loss: 4.1104 - accuracy: 0.9107 - mse: 4.1104 - val_loss: 0.0893 - val_accuracy: 0.9107 - val_mse: 0.0893
# Epoch 21/100
# 20/20 [==============================] - 0s 2ms/step - loss: 3.6906 - accuracy: 0.9147 - mse: 3.6906 - val_loss: 0.0893 - val_accuracy: 0.9107 - val_mse: 0.0893
# Epoch 22/100
# 20/20 [==============================] - 0s 2ms/step - loss: 3.3562 - accuracy: 0.9147 - mse: 3.3562 - val_loss: 0.0893 - val_accuracy: 0.9107 - val_mse: 0.0893
# Epoch 23/100
# 20/20 [==============================] - 0s 2ms/step - loss: 3.2114 - accuracy: 0.9167 - mse: 3.2114 - val_loss: 0.0893 - val_accuracy: 0.9107 - val_mse: 0.0893
# Epoch 24/100
# 20/20 [==============================] - 0s 2ms/step - loss: 2.8270 - accuracy: 0.9187 - mse: 2.8270 - val_loss: 0.0893 - val_accuracy: 0.9107 - val_mse: 0.0893
# Epoch 25/100
# 20/20 [==============================] - 0s 2ms/step - loss: 2.6249 - accuracy: 0.9187 - mse: 2.6249 - val_loss: 0.0893 - val_accuracy: 0.9107 - val_mse: 0.0893
# Epoch 26/100
# 20/20 [==============================] - 0s 2ms/step - loss: 2.4001 - accuracy: 0.9206 - mse: 2.4001 - val_loss: 0.0893 - val_accuracy: 0.9107 - val_mse: 0.0893
# Epoch 27/100
# 20/20 [==============================] - 0s 2ms/step - loss: 2.1993 - accuracy: 0.9206 - mse: 2.1993 - val_loss: 0.0893 - val_accuracy: 0.9107 - val_mse: 0.0893
# Epoch 28/100
# 20/20 [==============================] - 0s 2ms/step - loss: 2.0205 - accuracy: 0.9206 - mse: 2.0205 - val_loss: 0.0893 - val_accuracy: 0.9107 - val_mse: 0.0893
# Epoch 29/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.8541 - accuracy: 0.9206 - mse: 1.8541 - val_loss: 0.0893 - val_accuracy: 0.9107 - val_mse: 0.0893
# Epoch 30/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.6996 - accuracy: 0.9206 - mse: 1.6996 - val_loss: 0.0893 - val_accuracy: 0.9107 - val_mse: 0.0893
# Epoch 31/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.5285 - accuracy: 0.9206 - mse: 1.5285 - val_loss: 0.0893 - val_accuracy: 0.9107 - val_mse: 0.0893
# Epoch 32/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.3946 - accuracy: 0.9206 - mse: 1.3946 - val_loss: 0.0893 - val_accuracy: 0.9107 - val_mse: 0.0893
# Epoch 33/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.2612 - accuracy: 0.9206 - mse: 1.2612 - val_loss: 0.0893 - val_accuracy: 0.9107 - val_mse: 0.0893
# Epoch 34/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.1491 - accuracy: 0.9206 - mse: 1.1491 - val_loss: 0.0893 - val_accuracy: 0.9107 - val_mse: 0.0893
# Epoch 35/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.0294 - accuracy: 0.9206 - mse: 1.0294 - val_loss: 0.0893 - val_accuracy: 0.9107 - val_mse: 0.0893
# Epoch 36/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.9205 - accuracy: 0.9206 - mse: 0.9205 - val_loss: 0.0893 - val_accuracy: 0.9107 - val_mse: 0.0893
# Epoch 37/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.8351 - accuracy: 0.9206 - mse: 0.8351 - val_loss: 0.0893 - val_accuracy: 0.9107 - val_mse: 0.0893
# Epoch 38/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.7786 - accuracy: 0.9206 - mse: 0.7786 - val_loss: 0.0893 - val_accuracy: 0.9107 - val_mse: 0.0893
# Epoch 39/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6644 - accuracy: 0.9206 - mse: 0.6644 - val_loss: 0.0893 - val_accuracy: 0.9107 - val_mse: 0.0893
# Epoch 40/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6127 - accuracy: 0.9206 - mse: 0.6127 - val_loss: 0.0893 - val_accuracy: 0.9107 - val_mse: 0.0893
# Epoch 41/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5301 - accuracy: 0.9206 - mse: 0.5301 - val_loss: 0.0893 - val_accuracy: 0.9107 - val_mse: 0.0893
# Epoch 42/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4839 - accuracy: 0.9206 - mse: 0.4839 - val_loss: 0.0893 - val_accuracy: 0.9107 - val_mse: 0.0893
# Epoch 43/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4229 - accuracy: 0.9206 - mse: 0.4229 - val_loss: 0.0893 - val_accuracy: 0.9107 - val_mse: 0.0893
# Epoch 44/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3954 - accuracy: 0.9206 - mse: 0.3954 - val_loss: 0.0893 - val_accuracy: 0.9107 - val_mse: 0.0893
# Epoch 45/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3378 - accuracy: 0.9206 - mse: 0.3378 - val_loss: 0.0893 - val_accuracy: 0.9107 - val_mse: 0.0893
# Epoch 46/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3103 - accuracy: 0.9206 - mse: 0.3103 - val_loss: 0.0893 - val_accuracy: 0.9107 - val_mse: 0.0893
# Epoch 47/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2714 - accuracy: 0.9206 - mse: 0.2714 - val_loss: 0.0893 - val_accuracy: 0.9107 - val_mse: 0.0893
# Epoch 48/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2440 - accuracy: 0.9206 - mse: 0.2440 - val_loss: 0.0893 - val_accuracy: 0.9107 - val_mse: 0.0893
# Epoch 49/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2236 - accuracy: 0.9206 - mse: 0.2236 - val_loss: 0.0893 - val_accuracy: 0.9107 - val_mse: 0.0893
# Epoch 50/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1991 - accuracy: 0.9206 - mse: 0.1991 - val_loss: 0.0893 - val_accuracy: 0.9107 - val_mse: 0.0893
# Epoch 51/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1797 - accuracy: 0.9206 - mse: 0.1797 - val_loss: 0.0893 - val_accuracy: 0.9107 - val_mse: 0.0893
# Epoch 52/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1670 - accuracy: 0.9206 - mse: 0.1670 - val_loss: 0.0893 - val_accuracy: 0.9107 - val_mse: 0.0893
# Epoch 53/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1516 - accuracy: 0.9206 - mse: 0.1516 - val_loss: 0.0893 - val_accuracy: 0.9107 - val_mse: 0.0893
# Epoch 54/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1390 - accuracy: 0.9206 - mse: 0.1390 - val_loss: 0.0893 - val_accuracy: 0.9107 - val_mse: 0.0893
# Epoch 55/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1190 - accuracy: 0.9206 - mse: 0.1190 - val_loss: 0.0893 - val_accuracy: 0.9107 - val_mse: 0.0893
# Epoch 56/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1136 - accuracy: 0.9206 - mse: 0.1136 - val_loss: 0.0893 - val_accuracy: 0.9107 - val_mse: 0.0893
# Epoch 57/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1027 - accuracy: 0.9206 - mse: 0.1027 - val_loss: 0.0893 - val_accuracy: 0.9107 - val_mse: 0.0893
# Epoch 58/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0997 - accuracy: 0.9206 - mse: 0.0997 - val_loss: 0.0893 - val_accuracy: 0.9107 - val_mse: 0.0893
# Epoch 59/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0949 - accuracy: 0.9206 - mse: 0.0949 - val_loss: 0.0893 - val_accuracy: 0.9107 - val_mse: 0.0893
# Epoch 60/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0922 - accuracy: 0.9206 - mse: 0.0922 - val_loss: 0.0893 - val_accuracy: 0.9107 - val_mse: 0.0893
# Epoch 61/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0890 - accuracy: 0.9206 - mse: 0.0890 - val_loss: 0.0893 - val_accuracy: 0.9107 - val_mse: 0.0893
# Epoch 62/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0873 - accuracy: 0.9206 - mse: 0.0873 - val_loss: 0.0893 - val_accuracy: 0.9107 - val_mse: 0.0893
# Epoch 63/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0855 - accuracy: 0.9206 - mse: 0.0855 - val_loss: 0.0893 - val_accuracy: 0.9107 - val_mse: 0.0893
# Epoch 64/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0838 - accuracy: 0.9206 - mse: 0.0838 - val_loss: 0.0893 - val_accuracy: 0.9107 - val_mse: 0.0893
# Epoch 65/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0828 - accuracy: 0.9206 - mse: 0.0828 - val_loss: 0.0893 - val_accuracy: 0.9107 - val_mse: 0.0893
# Epoch 66/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0815 - accuracy: 0.9206 - mse: 0.0815 - val_loss: 0.0893 - val_accuracy: 0.9107 - val_mse: 0.0893
# Epoch 67/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0810 - accuracy: 0.9206 - mse: 0.0810 - val_loss: 0.0893 - val_accuracy: 0.9107 - val_mse: 0.0893
# Epoch 68/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0800 - accuracy: 0.9206 - mse: 0.0800 - val_loss: 0.0893 - val_accuracy: 0.9107 - val_mse: 0.0893
# Epoch 69/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0797 - accuracy: 0.9206 - mse: 0.0797 - val_loss: 0.0893 - val_accuracy: 0.9107 - val_mse: 0.0893
# Epoch 70/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0792 - accuracy: 0.9206 - mse: 0.0792 - val_loss: 0.0893 - val_accuracy: 0.9107 - val_mse: 0.0893
# Epoch 71/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0787 - accuracy: 0.9206 - mse: 0.0787 - val_loss: 0.0893 - val_accuracy: 0.9107 - val_mse: 0.0893
# Epoch 72/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0785 - accuracy: 0.9206 - mse: 0.0785 - val_loss: 0.0893 - val_accuracy: 0.9107 - val_mse: 0.0893
# Epoch 73/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0782 - accuracy: 0.9206 - mse: 0.0782 - val_loss: 0.0893 - val_accuracy: 0.9107 - val_mse: 0.0893
# Epoch 74/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0780 - accuracy: 0.9206 - mse: 0.0780 - val_loss: 0.0893 - val_accuracy: 0.9107 - val_mse: 0.0893
# Epoch 75/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0779 - accuracy: 0.9206 - mse: 0.0779 - val_loss: 0.0893 - val_accuracy: 0.9107 - val_mse: 0.0893
# Epoch 76/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0778 - accuracy: 0.9226 - mse: 0.0778 - val_loss: 0.0893 - val_accuracy: 0.9107 - val_mse: 0.0893
# Epoch 77/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0777 - accuracy: 0.9226 - mse: 0.0777 - val_loss: 0.0893 - val_accuracy: 0.9107 - val_mse: 0.0893
# Epoch 78/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0776 - accuracy: 0.9226 - mse: 0.0776 - val_loss: 0.0893 - val_accuracy: 0.9107 - val_mse: 0.0893
# Epoch 79/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0776 - accuracy: 0.9226 - mse: 0.0776 - val_loss: 0.0893 - val_accuracy: 0.9107 - val_mse: 0.0893
# Epoch 80/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0775 - accuracy: 0.9226 - mse: 0.0775 - val_loss: 0.0893 - val_accuracy: 0.9107 - val_mse: 0.0893
# Epoch 81/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0775 - accuracy: 0.9226 - mse: 0.0775 - val_loss: 0.0893 - val_accuracy: 0.9107 - val_mse: 0.0893
# Epoch 82/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0774 - accuracy: 0.9226 - mse: 0.0774 - val_loss: 0.0893 - val_accuracy: 0.9107 - val_mse: 0.0893
# Epoch 83/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0774 - accuracy: 0.9226 - mse: 0.0774 - val_loss: 0.0893 - val_accuracy: 0.9107 - val_mse: 0.0893
# Epoch 84/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0774 - accuracy: 0.9226 - mse: 0.0774 - val_loss: 0.0893 - val_accuracy: 0.9107 - val_mse: 0.0893
# Epoch 85/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0774 - accuracy: 0.9226 - mse: 0.0774 - val_loss: 0.0893 - val_accuracy: 0.9107 - val_mse: 0.0893
# Epoch 86/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0774 - accuracy: 0.9226 - mse: 0.0774 - val_loss: 0.0893 - val_accuracy: 0.9107 - val_mse: 0.0893
# Epoch 87/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0774 - accuracy: 0.9226 - mse: 0.0774 - val_loss: 0.0893 - val_accuracy: 0.9107 - val_mse: 0.0893
# Epoch 88/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0774 - accuracy: 0.9226 - mse: 0.0774 - val_loss: 0.0893 - val_accuracy: 0.9107 - val_mse: 0.0893
# Epoch 89/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0774 - accuracy: 0.9226 - mse: 0.0774 - val_loss: 0.0893 - val_accuracy: 0.9107 - val_mse: 0.0893
# Epoch 90/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0774 - accuracy: 0.9226 - mse: 0.0774 - val_loss: 0.0893 - val_accuracy: 0.9107 - val_mse: 0.0893
# Epoch 91/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0774 - accuracy: 0.9226 - mse: 0.0774 - val_loss: 0.0893 - val_accuracy: 0.9107 - val_mse: 0.0893
# Epoch 92/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0774 - accuracy: 0.9226 - mse: 0.0774 - val_loss: 0.0893 - val_accuracy: 0.9107 - val_mse: 0.0893
# Epoch 93/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0774 - accuracy: 0.9226 - mse: 0.0774 - val_loss: 0.0893 - val_accuracy: 0.9107 - val_mse: 0.0893
# Epoch 94/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0774 - accuracy: 0.9226 - mse: 0.0774 - val_loss: 0.0893 - val_accuracy: 0.9107 - val_mse: 0.0893
# Epoch 95/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0774 - accuracy: 0.9226 - mse: 0.0774 - val_loss: 0.0893 - val_accuracy: 0.9107 - val_mse: 0.0893
# Epoch 96/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0774 - accuracy: 0.9226 - mse: 0.0774 - val_loss: 0.0893 - val_accuracy: 0.9107 - val_mse: 0.0893
# Epoch 97/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0774 - accuracy: 0.9226 - mse: 0.0774 - val_loss: 0.0893 - val_accuracy: 0.9107 - val_mse: 0.0893
# Epoch 98/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0774 - accuracy: 0.9226 - mse: 0.0774 - val_loss: 0.0893 - val_accuracy: 0.9107 - val_mse: 0.0893
# Epoch 99/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0774 - accuracy: 0.9226 - mse: 0.0774 - val_loss: 0.0893 - val_accuracy: 0.9107 - val_mse: 0.0893
# Epoch 100/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0774 - accuracy: 0.9226 - mse: 0.0774 - val_loss: 0.0893 - val_accuracy: 0.9107 - val_mse: 0.0893
# 8/8 [==============================] - 0s 925us/step - loss: 0.0875 - accuracy: 0.9125 - mse: 0.0875
# 8/8 [==============================] - 0s 781us/step

# %% [markdown]
# #### Epoch Results
# * 100 Epochs
# * Loss (MSE): 0.0875
# * Accuracy: 0.9125
#
# Now that we've got our predictions, lets discretize them to binary values for legendary or not.

# %%
# Discretize y_pred to true or false using y_test
y_pred = np.where(y_pred > 0.5, 1, 0)
y_test = np.where(y_test > 0.5, 1, 0)

# Confusion Matrix with labels
cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix     :  Predicted Legendary | Predicted Non-Legendary")
print("Actual Legendary     :          ", cm[0][0], "                  ", cm[0][1])
print("Actual Non-Legendary :          ", cm[1][0], "                   ", cm[1][1])
# Out:
# Confusion Matrix     :  Predicted Legendary | Predicted Non-Legendary
# Actual Legendary     :           219                    0
# Actual Non-Legendary :           21                     0

# %% [markdown]
# After discretizing, we can analyze our confusion matrix.  Its odd that it only predicts legendary, as last week's model had non-legendary predictions.  However, I will take a false positive over a false negative.
